# %% [markdown]
# <a href="https://colab.research.google.com/github/YiHui000/Micro-assignment-2/blob/main/COVID19_DATA_ANALYSIS_CLASS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COVID 19 Data Analysis

# %% [markdown]
# **Description:** This script will read the latest data from the New York Times' county-level COVID-19 database at https://github.com/nytimes/covid-19-data/blob/master/us-counties.csv, filter the data for a chosen county in a chosen state, calculate the daily count of new cases and new deaths, print the most recent 28 days' worth of data for the selected county, and save the county's data for all dates to a comma-separated value (.csv) file on your computer. The printed data can be copied and pasted directly into a spreadsheet for further analysis and visualization.
#
# **Note:** For information about the data, see https://github.com/nytimes/covid-19-data.
#
# **Note:** After you have run the script one time in a given Anaconda environment, you may reduce the script's execution time by adding a `#` in front of `pip install pandas`. For example, `#pip install pandas` instead of `pip install pandas`. The `#` will tell Python to skip the code without running it.

# %% [markdown]
# # Task 1 : Environment Set up

# %% [markdown]
# Import all required libraries that are needed for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Task 2 :  Data Collection

# %% [markdown]
# Use nytimes github repository as a data source to collect the covid 19 data in real time and ingest it into colab notebook for data anlysis purpose

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
df
# Out:
#                date      county       state     fips  cases  deaths
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...             ...         ...         ...      ...    ...     ...
# 2115626  2022-01-14  Sweetwater     Wyoming  56037.0   8859   112.0
# 2115627  2022-01-14       Teton     Wyoming  56039.0   8057    14.0
# 2115628  2022-01-14       Uinta     Wyoming  56041.0   4522    34.0
# 2115629  2022-01-14    Washakie     Wyoming  56043.0   1961    41.0
# 2115630  2022-01-14      Weston     Wyoming  56045.0   1291    16.0
#
# [2115631 rows x 6 columns]

# %%
df.tail(10)
# Out:
#                date      county    state     fips  cases  deaths
# 2115621  2022-01-14    Niobrara  Wyoming  56027.0    519     8.0
# 2115622  2022-01-14        Park  Wyoming  56029.0   5930   122.0
# 2115623  2022-01-14      Platte  Wyoming  56031.0   1643    37.0
# 2115624  2022-01-14    Sheridan  Wyoming  56033.0   6504    63.0
# 2115625  2022-01-14    Sublette  Wyoming  56035.0   1598    24.0
# 2115626  2022-01-14  Sweetwater  Wyoming  56037.0   8859   112.0
# 2115627  2022-01-14       Teton  Wyoming  56039.0   8057    14.0
# 2115628  2022-01-14       Uinta  Wyoming  56041.0   4522    34.0
# 2115629  2022-01-14    Washakie  Wyoming  56043.0   1961    41.0
# 2115630  2022-01-14      Weston  Wyoming  56045.0   1291    16.0

# %%
df.head(10)
# Out:
#          date       county       state     fips  cases  deaths
# 0  2020-01-21    Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22    Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23    Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24         Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24    Snohomish  Washington  53061.0      1     0.0
# 5  2020-01-25       Orange  California   6059.0      1     0.0
# 6  2020-01-25         Cook    Illinois  17031.0      1     0.0
# 7  2020-01-25    Snohomish  Washington  53061.0      1     0.0
# 8  2020-01-26     Maricopa     Arizona   4013.0      1     0.0
# 9  2020-01-26  Los Angeles  California   6037.0      1     0.0

# %% [markdown]
# # Task 3 : Data Wrangling and EDA (Exploratory Data Analysis)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
Snohomish = ['fips']
df.drop(Snohomish, inplace=True, axis=1)
df
# Out:
#                date      county       state  cases  deaths
# 0        2020-01-21   Snohomish  Washington      1     0.0
# 1        2020-01-22   Snohomish  Washington      1     0.0
# 2        2020-01-23   Snohomish  Washington      1     0.0
# 3        2020-01-24        Cook    Illinois      1     0.0
# 4        2020-01-24   Snohomish  Washington      1     0.0
# ...             ...         ...         ...    ...     ...
# 2115626  2022-01-14  Sweetwater     Wyoming   8859   112.0
# 2115627  2022-01-14       Teton     Wyoming   8057    14.0
# 2115628  2022-01-14       Uinta     Wyoming   4522    34.0
# 2115629  2022-01-14    Washakie     Wyoming   1961    41.0
# 2115630  2022-01-14      Weston     Wyoming   1291    16.0
#
# [2115631 rows x 5 columns]

# %%
Washington = df[(df['state']=='Washington')& (df['county'] == 'Snohomish')]
Washington.tail(200)
# Out:
#                date     county       state   cases  deaths
# 1468899  2021-06-29  Snohomish  Washington   40178   601.0
# 1472144  2021-06-30  Snohomish  Washington   40231   604.0
# 1475390  2021-07-01  Snohomish  Washington   40284   605.0
# 1478636  2021-07-02  Snohomish  Washington   40330   605.0
# 1481883  2021-07-03  Snohomish  Washington   40330   605.0
# ...             ...        ...         ...     ...     ...
# 2102466  2022-01-10  Snohomish  Washington   96172   858.0
# 2105717  2022-01-11  Snohomish  Washington   97841   857.0
# 2108968  2022-01-12  Snohomish  Washington   99803   866.0
# 2112220  2022-01-13  Snohomish  Washington  101818   870.0
# 2115472  2022-01-14  Snohomish  Washington  103790   872.0
#
# [200 rows x 5 columns]

# %%
Washington.head(200)
# Out:
#               date     county       state  cases  deaths
# 0       2020-01-21  Snohomish  Washington      1     0.0
# 1       2020-01-22  Snohomish  Washington      1     0.0
# 2       2020-01-23  Snohomish  Washington      1     0.0
# 4       2020-01-24  Snohomish  Washington      1     0.0
# 7       2020-01-25  Snohomish  Washington      1     0.0
# ...            ...        ...         ...    ...     ...
# 398644  2020-08-03  Snohomish  Washington   5896   201.0
# 401860  2020-08-04  Snohomish  Washington   5957   202.0
# 405078  2020-08-05  Snohomish  Washington   6033   202.0
# 408298  2020-08-06  Snohomish  Washington   6074   202.0
# 411517  2020-08-07  Snohomish  Washington   6112   202.0
#
# [200 rows x 5 columns]

# %%
sns.histplot(data = Washington, x='cases', y = 'deaths',color='Pink')

# %%
fig = plt.figure(figsize=(40, 11))
sns.barplot(data = Washington, x = 'date', y='deaths')

# %% [markdown]
# # Task4: Understand NY covid 19 data in last 30 days

# %%
New_York = Days[(df['state']=='New York') & (df['county'] =='New York City')] 
Days= df[(df['date'] > '2021-12-16') & (df['date']< '2022-01-15')]
New_York
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                date         county     state    cases   deaths
# 2023236  2021-12-17  New York City  New York  1219276  35045.0
# 2026487  2021-12-18  New York City  New York  1219276  35045.0
# 2029738  2021-12-19  New York City  New York  1237462  35066.0
# 2032988  2021-12-20  New York City  New York  1249755  35067.0
# 2036238  2021-12-21  New York City  New York  1267713  35100.0
# 2039488  2021-12-22  New York City  New York  1284470  35126.0
# 2042737  2021-12-23  New York City  New York  1302298  35151.0
# 2045987  2021-12-24  New York City  New York  1317511  35151.0
# 2049237  2021-12-25  New York City  New York  1317511  35151.0
# 2052487  2021-12-26  New York City  New York  1372339  35151.0
# 2055737  2021-12-27  New York City  New York  1394411  35200.0
# ...

# %%
New_York.shape
# Out:
# (29, 5)

# %%
sum(New_York['cases'])
# Out:
# 45874622

# %%
sum(New_York['deaths'])
# Out:
# 1029178.0

# %%
fig = plt.figure(figsize=(50, 20))
sns.barplot(data = New_York , x= "date", y = "deaths")

# %%
sns.histplot(data = New_York , x= "cases", y = "deaths")

# %% [markdown]
# # Comparing Covid 19 data with different states

# %%
df_comparing = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
df_comparing

df_comparing.query("state == 'New York' or state == 'Florida' or state=='Washington'")
df1=df_comparing.query("state == 'New York' or state == 'Florida' or state == 'Washington'")
df1=df1[(df1['date']>'2021-12-16')]
df2=['county']
df1.drop(df2, inplace=True, axis=1)
df1
# Out:
#                date       state     fips  cases  deaths
# 2021682  2021-12-17     Florida  12001.0  40515   537.0
# 2021683  2021-12-17     Florida  12003.0   6027   122.0
# 2021684  2021-12-17     Florida  12005.0  32114   700.0
# 2021685  2021-12-17     Florida  12007.0   5363   125.0
# 2021686  2021-12-17     Florida  12009.0  82434  1777.0
# ...             ...         ...      ...    ...     ...
# 2115476  2022-01-14  Washington  53069.0    332     5.0
# 2115477  2022-01-14  Washington  53071.0  10786   120.0
# 2115478  2022-01-14  Washington  53073.0  25852   217.0
# 2115479  2022-01-14  Washington  53075.0   6867    83.0
# 2115480  2022-01-14  Washington  53077.0  54191   668.0
#
# [4785 rows x 5 columns]

# %%
sns.barplot(data =df1  , x= "state", y = "deaths")

# %% [markdown]
# # Conclusion

# %% [markdown]
# Below are the conclusions:
#
#
#
# 1.   Conclusion 1
#      --New York state have 45874622 cases and 1029178 people dead due to COVID-19 between 12/16/2021 and 01/25/2022. according to the bar diagram shows that when the days is near to the 01/15/2022, there are more people dead.
# 2.   Conclusion 2
#      --According to the bar diagram shows that there are more people dead due to COVID-19 in New York State than Florida and Washington.
